# %%
# Integers
x = 789
y = 2

# Addition
print(x + y)
# Out:
# 791

# %%
# Floats
x = 4.3
y = 2.3

# Addition
print(x + y)

# Subtraction
print(x - y)

# Multiplication
print(x * y)

# Returns the quotient
print(x / y)

# Returns the remainder
print(x % y) 

# Absolute value
print(abs(x))

# x to the power y
print(x ** y)
# Out:
# 6.6
# 2.0
# 9.889999999999999
# 1.8695652173913044
# 2.0
# 4.3
# 28.64029241922775

# %%
# String
x = 'Fun'
y = 'Excel'

# Concatenate 
print(x + ' X ' + y)

# Repeat
print(x * 2)

# Subtract String - this will not work
print(x - y)
# Out:
# Fun X Excel
# FunFun
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3678093f58bf> in <module>
#      10
#      11 # Subtract String
# ---> 12 print(x - y)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# String
# Range Slicing
myName = 'Kunaal'
z1 = myName[2:] 

print(z1)

# Slicing
z2 = myName[0] + myName[5] 

print(z2)
# Out:
# naal
# Kl

# %%
# String
x = '2'
y = '1'

x + y
# Out:
# '21'

# %%
# String Methods
str.

# %%
str.capitalize('elephant')
# Out:
# 'Elephant'

# %%
str1 = "We love Data Science"
str2 = "404"
len(str1)
# Out:
# 20

# %%
str1.isdigit()
# Out:
# False

# %%
str2.isdigit()
# Out:
# True

# %%
str3 = 'like'
str1.replace('love', str3)
# Out:
# 'We like Data Science'

# %%
str1.find('love')
# Out:
# 3

# %%
str1
# Out:
# 'We love Data Science'

# %%
# Boolean
x = 4
y = 4
z = (x == y) # Comparison expression (Evaluates to false)
if z: # Conditional on truth/false value of 'z'
    print("We want to be a Data Scientist")
else: 
    print("We DO not want to be a Data Scientists")
# Out:
# We want to be a Data Scientist

# %%
if x:
    'here'
else: 
    'next gjj'
# Out:
# True

# %%
# Implicit Conversions
# A float
x = 6.0 

# An integer
y = 3 

# Divide `x` by `y`
z = x/y

# Check the type of `z`
type(z)
# Out:
# float

# %%
5/2
# Out:
# 2.5

# %%
# Explicit Conversion
x = 8
y = "Game of Thrones: Season "
fav_season = y + x
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-773ae15bc933> in <module>
#       2 x = 8
#       3 y = "Game of Thrones: Season "
# ----> 4 fav_season = y + x
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = 8
y = "Game of Thrones: Season "
fav_season = (y) + str(x)
print(fav_season)
# Out:
# Game of Thrones: Season 8

# %% [markdown]
# ## Inputs

# %%
name = input("Enter Employee Name ")
salary = input("Enter salary ")
company = input("Enter Company name ")

print("\n")
print("Printing Employee Details")
print("Name", "Salary", "Company")
print(name, salary, company)
# Out:
# Enter Employee Name ABC
# Enter salary 34k
# Enter Company name Dell
#
#
# Printing Employee Details
# Name Salary Company
# ABC 34k Dell

# %%
# program to calculate addition of two input numbers
first_number = int(input("Enter first number "))
second_number = int(input("Enter second number "))

print("\n")
print("First Number:", first_number)
print("Second Number:", second_number)
sum1 = first_number + second_number
print("Addition of two number is: ", sum1)
# Out:
# Enter first number 5
# Enter second number 6
#
#
# First Number: 5
# Second Number: 6
# Addition of two number is:  11

# %%
firstName = input("Enter First Name ")
lastName = input("Enter Last Name ")
organization = input("Enter Organization Name ")

print("\n")
print('{0}, {1} works at {2}'.format(firstName, lastName, organization))
print('{1}, {0} works at {2}'.format(firstName, lastName, organization))
print('FirstName {0}, LastName {1} works at {2}'.format(firstName, lastName, organization))
print('{0}, {1} {0}, {1} works at {2}'.format(firstName, lastName, organization))
# Out:
# Enter First Name Kunaal
# Enter Last Name Nail
# Enter Organization Name Dell
#
#
# Kunaal, Nail works at Dell
# Nail, Kunaal works at Dell
# FirstName Kunaal, LastName Nail works at Dell
# Kunaal, Nail Kunaal, Nail works at Dell

# %%
positive_number = float(input("Enter Positive Number "))
negative_number = float(input("Enter Negative Number "))

print("\n")
# sign '+' is for both positive and negative number
print('{:+f}; {:+f}'.format(positive_number, negative_number))

# sign '-' is only for negative number
print('{:f}; {:-f}'.format(positive_number, negative_number))
# Out:
# Enter Positive Number 5
# Enter Negative Number -5
#
#
# +5.000000; -5.000000
# 5.000000; -5.000000
