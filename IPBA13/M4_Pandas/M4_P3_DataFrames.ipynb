# %% [markdown]
# # DataFrames
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index.

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.read_excel('3_NEWS_Sales.xlsx',sheet_name='NEWS')

# %%
df
# Out:
#    Month  North  East  West  South
# 0    Jan   5143  2027  7256   7428
# 1    Feb   9492  3506  7047   8374
# 2    Mar   6223  1419  7866   3485
# 3    Apr   6537  2986  7062   8061
# 4    May   9186  4614  5657   9003
# 5    Jun   6999  8625  5130   2725
# 6    Jul   4882  2341  7418   8768
# 7    Aug   7762  5923  6715   3117
# 8    Sep   9629  6063  4306   8304
# 9    Oct   2239  5743  5530   3131
# 10   Nov   5232  5784  6924   3996
# 11   Dec   1455  4896  3557   1005

# %%
df.set_index('Month', inplace = True)
df
# Out:
#        North  East  West  South
# Month
# Jan     5143  2027  7256   7428
# Feb     9492  3506  7047   8374
# Mar     6223  1419  7866   3485
# Apr     6537  2986  7062   8061
# May     9186  4614  5657   9003
# Jun     6999  8625  5130   2725
# Jul     4882  2341  7418   8768
# Aug     7762  5923  6715   3117
# Sep     9629  6063  4306   8304
# Oct     2239  5743  5530   3131
# Nov     5232  5784  6924   3996
# Dec     1455  4896  3557   1005

# %% [markdown]
# ## Selection and Indexing
#
# Let's learn the various methods to grab data from a DataFrame

# %%
df['North']
# Out:
# Month
# Jan    5143
# Feb    9492
# Mar    6223
# Apr    6537
# May    9186
# Jun    6999
# Jul    4882
# Aug    7762
# Sep    9629
# Oct    2239
# Nov    5232
# Dec    1455
# Name: North, dtype: int64

# %%
# Pass a list of column names
df[['North','South']]
# Out:
#        North  South
# Month
# Jan     5143   7428
# Feb     9492   8374
# Mar     6223   3485
# Apr     6537   8061
# May     9186   9003
# Jun     6999   2725
# Jul     4882   8768
# Aug     7762   3117
# Sep     9629   8304
# Oct     2239   3131
# Nov     5232   3996
# Dec     1455   1005

# %%
df.loc['Jan']
# Out:
# North    5143
# East     2027
# West     7256
# South    7428
# Name: Jan, dtype: int64

# %% [markdown]
# DataFrame Columns are just Series

# %%
type(df['North'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Creating a new column:**

# %%
df['North_South'] = df['North'] + df['South']

# %%
df
# Out:
#        North  East  West  South  North_South
# Month
# Jan     5143  2027  7256   7428        12571
# Feb     9492  3506  7047   8374        17866
# Mar     6223  1419  7866   3485         9708
# Apr     6537  2986  7062   8061        14598
# May     9186  4614  5657   9003        18189
# Jun     6999  8625  5130   2725         9724
# Jul     4882  2341  7418   8768        13650
# Aug     7762  5923  6715   3117        10879
# Sep     9629  6063  4306   8304        17933
# Oct     2239  5743  5530   3131         5370
# Nov     5232  5784  6924   3996         9228
# Dec     1455  4896  3557   1005         2460

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('North_South',axis=1)
# Out:
#        North  East  West  South
# Month
# Jan     5143  2027  7256   7428
# Feb     9492  3506  7047   8374
# Mar     6223  1419  7866   3485
# Apr     6537  2986  7062   8061
# May     9186  4614  5657   9003
# Jun     6999  8625  5130   2725
# Jul     4882  2341  7418   8768
# Aug     7762  5923  6715   3117
# Sep     9629  6063  4306   8304
# Oct     2239  5743  5530   3131
# Nov     5232  5784  6924   3996
# Dec     1455  4896  3557   1005

# %%
# Not inplace unless specified!
df
# Out:
#        North  East  West  South  North_South
# Month
# Jan     5143  2027  7256   7428        12571
# Feb     9492  3506  7047   8374        17866
# Mar     6223  1419  7866   3485         9708
# Apr     6537  2986  7062   8061        14598
# May     9186  4614  5657   9003        18189
# Jun     6999  8625  5130   2725         9724
# Jul     4882  2341  7418   8768        13650
# Aug     7762  5923  6715   3117        10879
# Sep     9629  6063  4306   8304        17933
# Oct     2239  5743  5530   3131         5370
# Nov     5232  5784  6924   3996         9228
# Dec     1455  4896  3557   1005         2460

# %%
df.drop('North_South',axis=1,inplace=True)

# %%
df
# Out:
#        North  East  West  South
# Month
# Jan     5143  2027  7256   7428
# Feb     9492  3506  7047   8374
# Mar     6223  1419  7866   3485
# Apr     6537  2986  7062   8061
# May     9186  4614  5657   9003
# Jun     6999  8625  5130   2725
# Jul     4882  2341  7418   8768
# Aug     7762  5923  6715   3117
# Sep     9629  6063  4306   8304
# Oct     2239  5743  5530   3131
# Nov     5232  5784  6924   3996
# Dec     1455  4896  3557   1005

# %% [markdown]
# Can also drop rows this way:

# %%
df.drop('Jan',axis=0)
# Out:
#        North  East  West  South
# Month
# Feb     9492  3506  7047   8374
# Mar     6223  1419  7866   3485
# Apr     6537  2986  7062   8061
# May     9186  4614  5657   9003
# Jun     6999  8625  5130   2725
# Jul     4882  2341  7418   8768
# Aug     7762  5923  6715   3117
# Sep     9629  6063  4306   8304
# Oct     2239  5743  5530   3131
# Nov     5232  5784  6924   3996
# Dec     1455  4896  3557   1005

# %% [markdown]
# ** Selecting Rows**

# %%
df.loc['Jan']
# Out:
# North    5143
# East     2027
# West     7256
# South    7428
# Name: Jan, dtype: int64

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[2]
# Out:
# North    6223
# East     1419
# West     7866
# South    3485
# Name: Mar, dtype: int64

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.loc['Mar','South']
# Out:
# 3485

# %%
df.loc[['Feb','Mar'],['East','West']]
# Out:
#        East  West
# Month
# Feb    3506  7047
# Mar    1419  7866

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df
# Out:
#        North  East  West  South
# Month
# Jan     5143  2027  7256   7428
# Feb     9492  3506  7047   8374
# Mar     6223  1419  7866   3485
# Apr     6537  2986  7062   8061
# May     9186  4614  5657   9003
# Jun     6999  8625  5130   2725
# Jul     4882  2341  7418   8768
# Aug     7762  5923  6715   3117
# Sep     9629  6063  4306   8304
# Oct     2239  5743  5530   3131
# Nov     5232  5784  6924   3996
# Dec     1455  4896  3557   1005

# %%
df>5000
# Out:
#        North   East   West  South
# Month
# Jan     True  False   True   True
# Feb     True  False   True   True
# Mar     True  False   True  False
# Apr     True  False   True   True
# May     True  False   True   True
# Jun     True   True   True  False
# Jul    False  False   True   True
# Aug     True   True   True  False
# Sep     True   True  False   True
# Oct    False   True   True  False
# Nov     True   True   True  False
# Dec    False  False  False  False

# %%
df[df>5000]
# Out:
#         North    East    West   South
# Month
# Jan    5143.0     NaN  7256.0  7428.0
# Feb    9492.0     NaN  7047.0  8374.0
# Mar    6223.0     NaN  7866.0     NaN
# Apr    6537.0     NaN  7062.0  8061.0
# May    9186.0     NaN  5657.0  9003.0
# Jun    6999.0  8625.0  5130.0     NaN
# Jul       NaN     NaN  7418.0  8768.0
# Aug    7762.0  5923.0  6715.0     NaN
# Sep    9629.0  6063.0     NaN  8304.0
# Oct       NaN  5743.0  5530.0     NaN
# Nov    5232.0  5784.0  6924.0     NaN
# Dec       NaN     NaN     NaN     NaN

# %%
df[df['North']>8000]
# Out:
#        North  East  West  South
# Month
# Feb     9492  3506  7047   8374
# May     9186  4614  5657   9003
# Sep     9629  6063  4306   8304

# %%
df[df['North']>8000]['East']
# Out:
# Month
# Feb    3506
# May    4614
# Sep    6063
# Name: East, dtype: int64

# %%
df[df['North']>8000][['East','West']]
# Out:
#        East  West
# Month
# Feb    3506  7047
# May    4614  5657
# Sep    6063  4306

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df[(df['North']>8000) & (df['East'] > 5000)]
# Out:
#        North  East  West  South
# Month
# Sep     9629  6063  4306   8304
