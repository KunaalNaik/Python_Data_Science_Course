# %% [markdown]
# # Numpy
# ---
# ## Quiz

# %%
import numpy as np

# %% [markdown]
# ### Array Operations
# - What will this code print?

# %%
arr1 = np.arange(10)
arr2 = np.array([9,8,7,6,5,4,3,2,1,0])

# write a code to combine 2 arrays

# %% [markdown]
# ### Array Summary
# - What will this code print?

# %%
arr1 = np.arange(10) * 1
arr1.sum

# %% [markdown]
# ### Selection
# - How many values with this code print?

# %%
arr = [9,8,7,6,5,4,3,2,1,0]

arr[arr345 > 5]
