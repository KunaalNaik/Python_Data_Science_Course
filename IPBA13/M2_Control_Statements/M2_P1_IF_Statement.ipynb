# %% [markdown]
# # Introduction to Python
# ---
# ## If Statement
# - If
# - Else
# - Elif

# %% [markdown]
# ### If

# %%
if (2 > 3):    # Notice that a statement is followed by a :
    print ('Will it print this?')
else:
    print ('Or this?')
# Out:
# Or this?

# %%
if (2 > 3):    # Notice that a statement is followed by a :
print ('Will it print this?')
else:
print ('Or this?')
# Out:
#   File "<ipython-input-2-fa24036d501c>", line 2
#     print ('Will it print this?')
#     ^
# IndentationError: expected an indented block

# %%
if (2 > 3):
    print('sfsd')
    print('sfs')

print('no matter what')
# Out:
# no matter what

# %%
# we can also assign variable and then write a statement
i = 6

if (i > 3):    # Notice that a statement is followed by a :
    print ('Will it print this?')
else:
    print ('Or this?')
# Out:
# Will it print this?

# %% [markdown]
# ### If else

# %%
age = 45
if (age < 19):
    print("Not Eligible for applying a job")
    print("Currently the if Block")
else:
    print("Eligible")
    print("Currently the else Block")

print("I will be printed, no matter what!")
# Out:
# Eligible
# Currently the else Block
# I will be printed, no matter what!

# %%
age = 21
if (age < 19):
    print("Not Eligible for applying a job")
    print("Currently the if Block")
else:
    print("Eligible")
    print("Currently the else Block")
    
print("I will be printed, no matter what!")
# Out:
# Eligible
# Currently the else Block
# I will be printed, no matter what!

# %%
age = 21
if (age < 19):
    print()
    if ():
        print("Not Eligible for applying a job")
        print("Currently the if Block")
else:
    print("Eligible")
    print("Currently the else Block")
    
print("I will be printed, no matter what!")

# %% [markdown]
# ### If else elif

# %%
age = 11

if (age <= 12):
    print("Child")
elif (age >= 13 and age <=19) :
    print("Teen")
else:
    print("Adult")
# Out:
# Child

# %%
age = 18

if (age <= 12):
    print("Child")
elif (age >= 13 and age <=19) :
    print("Teen")
else:
    print("Adult")
# Out:
# Teen

# %%
age = 100

if (age <= 12):
    print("Child")
elif (age >= 13 and age <=19) :
    print("Teen")
else:
    print("Adult")
# Out:
# Adult

# %% [markdown]
# ### Note: Difference between "and" and "&"
# - and is a Logical AND that returns True if both the operands are true
# - ‘&’ is a bitwise operator in Python that acts on bits and performs bit by bit operation

# %%
age = 100

# %%
cond1 = (age >= 13 and age <=19) # use this and
cond2 = (age >= 13 & age <=19)

# %%
cond1
# Out:
# False

# %%
cond2
# Out:
# True
