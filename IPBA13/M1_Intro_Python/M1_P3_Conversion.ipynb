# %% [markdown]
# # Introduction to Python
# ---
# ## Conversion

# %% [markdown]
# ### Implicit

# %%
# Integer and Float - Addition, Subtract, Multiply
x = 50
y = 5.5

print(x + y)
print(x - y)
print(x * y)

# Converts to Float
# Out:
# 55.5
# 44.5
# 275.0

# %%
# Integer and Integer - Divide
x = 50
y = 5

print(x / y)

# Converts to Float
# Out:
# 10.0

# %%
# Integer and Integer - Power
x = 5
y = 5

print(x ** y)

# Does not convert to Float
# Out:
# 0.7071067811865476

# %% [markdown]
# ### Explicit

# %%
price = 49

# %%
txt = "For only "+ price +"  dollars!"
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ea59effa3e23> in <module>
# ----> 1 txt = "For only "+ price +"  dollars!"
#       2 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
sentence = 'Number of modules completed : '
modules = 5

# %%
# Integer and String

print(sentence + modules)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b809375be151> in <module>
#       1 # Integer and String
#       2
# ----> 3 print(sentence + modules)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Convert modules to String

print(sentence + str(modules))

# Works!
# Out:
# Number of modules completed : 5

# %%
# Convert sentence to Integer

print(int(sentence) + modules)

# Not Possible
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c63fe6c74220> in <module>
#       1 # Convert sentence to Integer
#       2
# ----> 3 print(int(sentence) + modules)
#       4
#       5 # Not Possible
#
# ValueError: invalid literal for int() with base 10: 'Number of modules completed : '

# %% [markdown]
# # Next Topic: Input/Output/Print
