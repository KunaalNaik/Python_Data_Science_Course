# %% [markdown]
# # Introduction to Python
# ---
# ## Data Types
# - Primitive
# - Containers (collection of Data)

# %% [markdown]
# ### Variable

# %%
# x is variable
# user chooses to define the name
# assign using single "="
x = 10

# %%
# print
x
# Out:
# 10

# %%
# or use print()
print(x)
# Out:
# 10

# %%
# re assign 
x = 55
print(x)
# Out:
# 55

# %%
# Order matters
x = 10

x = 55

# prints the latest assigned value
print(x)
# Out:
# 55

# %% [markdown]
# ### Primitive

# %% [markdown]
# #### Number
# - Integer
# - Float

# %%
x_integer = 49
x_integer
# Out:
# 49

# %%
x_float = 1.5
x_float
# Out:
# 1.5

# %% [markdown]
# #### Boolean

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
decision = True
decision
# Out:
# True

# %% [markdown]
# #### String

# %%
# using quotes denotes String
# use can use single or double quotes 
# python prefers single quotes
brand = 'Jigsaw Academy'
brand
# Out:
# 'Jigsaw Academy'

# %% [markdown]
# ### Summary
# | Data Type    | Example  |
# | :---         |  :----:  |
# | Number - Integer         | 55 |
# | Number - Float       | 1.5 |
# | Boolean         | True/False |
# | String   | "Jigsaw Academy" |

# %% [markdown]
# ### Containers (collection of data)
# #### built-in collection data types
# - List
# - Tuple
# - Set
# - Dictionary

# %% [markdown]
# #### List
# - Lists are used to store multiple items in a single variable
# - uses square bracket "[" or "]"
#
# ##### Usage
# - [x] Ordered
#     - It means that the items have a defined order, and that order will not change
# - [x] Changeable
#     - It means we can change, add, and remove items in a list after it has been created
# - [x] Allow Duplicates
#     - It means it can have items with the same value

# %%
age = [23,24,26,18,21]
age
# Out:
# [23, 24, 26, 18, 21]

# %%
names = ['Raj','Ram','Rahul','Prashant','Tanvi']
names
# Out:
# ['Raj', 'Ram', 'Rahul', 'Prashant', 'Tanvi']

# %% [markdown]
# #### Tuples
# - Tuples are used to store multiple items in a single variable
# - uses round bracket "(" or ")"
#
# ##### Usage
# - Tuples are more memory efficient than the lists
# - [x] Ordered
# - [ ] Changeable
# - [x] Allow Duplicates

# %%
constant = (10.2, 15.6, 21.5)
constant
# Out:
# (10.2, 15.6, 21.5)

# %% [markdown]
# #### Sets
# - Sets are used to store multiple items in a single variable
# - uses curly bracket "{" or "}"
#
# ##### Usage
# - Sets are more memory efficient than the lists
# - [ ] Ordered
# - [ ] Changeable
# - [ ] Allow Duplicates

# %%
data_science_tools = {'Python', 'Excel', 'SQL', 'PowerPoint'}

data_science_tools
# Out:
# {'Excel', 'PowerPoint', 'Python', 'SQL'}

# %% [markdown]
# #### Dictionary
# - Dictionaries are used to store data values in key:value pairs
# - uses curly bracket "{" or "}" with **key**
#
# ##### Usage
# - Dictionary are more memory efficient than the lists
# - [ ] Ordered
# - [ ] Changeable
# - [ ] Allow Duplicates

# %%
data_science_tools_priority = { 'priority 1' : 'Excel'
                      , 'priority 2' : 'SQL'
                      , 'priority 3' : 'Python'
                      , 'priority 4' : 'PowerPoint'}

data_science_tools_priority
# Out:
# {'priority 1': ['Excel', 'SQL'],
#  'priority 2': 'SQL',
#  'priority 3': 'Python',
#  'priority 4': 'PowerPoint'}

# %%
data_science_tools_priority['priority 1']

# %%
data_science_tools_priority = { 'priority 1' : ['Excel','SQL']
                      , 'priority 2' : 'SQL'
                      , 'priority 3' : 'Python'
                      , 'priority 4' : 'PowerPoint'}

data_science_tools_priority['priority 1']
# Out:
# ['Excel', 'SQL']

# %% [markdown]
# #### Array (Covered in future with Numpy)
# - An array is defined as a collection of items that are stored at contiguous memory locations
# - 2 variations
#     - package : array (import array as a)
#     - package : numpy (import numpy as np)

# %% [markdown]
# ##### package : array

# %%
# get previous list
age
# Out:
# [23, 24, 26, 18, 21]

# %%
import array as a

names_array = a.array("i", age)

# also
# names_array = a.array("i", [23, 24, 26, 18, 21])

names_array
# Out:
# array('i', [23, 24, 26, 18, 21])

# %% [markdown]
# ##### package : numpy

# %%
import numpy as np

names_np_array = np.array(age)

# also
# names_np_array = np.array([23, 24, 26, 18, 21])

names_np_array
# Out:
# array([23, 24, 26, 18, 21])

# %% [markdown]
# ### Container Summary

# %% [markdown]
# | Container    | Bracket  | Example |
# | :---         |  :----:  |    ---: |
# | List         | "["  "]" | ['Raj','Ram','Rahul','Prashant','Tanvi'] |
# | Tuples       | "("  ")" | (10.2, 15.6, 21.5) |
# | Sets         | "{"  "}" | {'Python', 'Excel', 'SQL', 'PowerPoint'} |
# | Dictionary   | "{"  "}" | { 'priority 1' : 'Excel' , 'priority 2' : 'SQL', 'priority 3' : 'Python', 'priority 4' : 'PowerPoint'}|

# %% [markdown]
# # Next Topic: Data Operations
